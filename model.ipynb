# %%
import pandas as pd

df = pd.read_csv("openalex_works.csv")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                            paper_id  \
# 0  https://openalex.org/W2896457183
# 1  https://openalex.org/W2250539671
# 2  https://openalex.org/W2963341956
# 3  https://openalex.org/W2965373594
# 4  https://openalex.org/W4292779060
#
#                                                title  publication_year  \
# 0  AI-Assisted Pipeline for Dynamic Generation of...              2018
# 1      Glove: Global Vectors for Word Representation              2014
# 2                                                NaN              2019
# 3  HISTORIAE, History of Socio-Cultural Transform...              2019
# 4  Aion Framework: Dimensional Emergence of AI Co...              2023
#
#    citation_count  referenced_works_count  \
# 0           45869                      55
# 1           33916                      28
# 2           33085                      52
# 3           17408                      45
# 4           14295                       0
#
# ...
